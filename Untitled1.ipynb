# %%
conda install --channel https://conda.anaconda.org/david_baddeley python-javabridge
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - python-javabridge -> python=2.7
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/tomgvero/opt/anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38hecd8cb5_0         2.9 MB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following packages will be UPDATED:
#
#   conda                                        4.8.5-py38_0 --> 4.10.3-py38hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# conda-4.10.3         | 2.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install numpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pydot
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                                            |failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - anaconda==2020.07 -> python[version='3.6.10|3.7.7|3.8.3',build='hf48f09d_2|hf48f09d_4|h26836e1_2']
#   - atomicwrites -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - attrs -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - autopep8 -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - backports -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - backports.functools_lru_cache -> python[version='>=2.7,<2.8.0a0']
#   - bleach -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - brotlipy -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - colorama -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda-verify -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda[version='>=4.10.3'] -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - contextlib2 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - defusedxml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - filelock -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - flake8 -> python[version='>=3.9,<3.10.0a0']
#   - flask -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - glob2 -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - h5py -> python[version='<3']
#   - html5lib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.9,<3.10.0a0']
#   - imagesize -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - ipywidgets -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - isort -> python[version='>=3.9,<3.10.0a0']
#   - jdcal -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - jupyter_console -> python[version='>=3.9,<3.10.0a0']
#   - matplotlib-base -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - mock -> python[version='>=3.9,<3.10.0a0']
#   - more-itertools -> python[version='>=3.9,<3.10.0a0']
#   - nose -> python[version='>=3.9,<3.10.0a0']
#   - numba -> python=3.4
#   - olefile -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - path -> python[version='>=2.7,<2.8.0a0']
#   - pickleshare -> python[version='>=3.9,<3.10.0a0']
#   - prometheus_client -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - pycparser -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0']
#   - pyflakes -> python[version='>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.9,<3.10.0a0']
#   - pyparsing -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pyrsistent -> python[version='>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pytz -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - qtpy -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - rope -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - snowballstemmer -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - sortedcollections -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - sphinxcontrib-websupport -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - tblib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - typing_extensions -> python[version='>=3.9,<3.10.0a0']
#   - watchdog -> python[version='>=3.5,<3.6.0a0']
#   - werkzeug -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - wheel -> python[version='>=3.9,<3.10.0a0']
#   - wurlitzer -> python[version='<3.4']
#   - xlrd -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - xlsxwriter -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - xmltodict -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - yapf -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - zict -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - zope.event -> python[version='>=3.5,<3.6.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package tk conflicts for:
# pycurl -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter_console -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-matrix -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-mgcv -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-rcppeigen -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-labeling -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-jsonlite -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# diff-match-patch -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# partd -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# singledispatch -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-xts -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-stringr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-tibble -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jinja2 -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# importlib_metadata -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# networkx -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tqdm -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-irdisplay -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-car -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-quantreg -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# certifi -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-lattice -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# curl -> krb5[version='>=1.17.1,<1.18.0a0'] -> tk[version='>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-iterators -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# lxml -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-lazyeval -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# rope -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-mass -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# qtconsole -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# et_xmlfile -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-htmlhelp -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-memoise -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# alabaster -> python[version='>=2.7,<2.8.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.10,<8.7.0a0']
# xmltodict -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sqlalchemy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-bitops -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-yaml -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# anaconda==2020.07 -> pillow==7.2.0=py37ha54b6ba_0 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# unicodecsv -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyterlab_server -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numpy-base -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# imagesize -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# path.py -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-jsonrpc-server -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# h5py -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# spyder-kernels -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jdcal -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# colorama -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# qdarkstyle -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rbokeh -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# astroid -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-highr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# babel -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-htmlwidgets -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# zope -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-randomforest -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-nloptr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sympy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pandas -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# distributed -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-zoo -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-markdown -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-survival -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-cluster -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# joblib -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter_client -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nltk -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-language-server -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ruamel_yaml -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# wheel -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nose -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# gevent -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-bh -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# json5 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# heapdict -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# defusedxml -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# parso -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pip -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-scales -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# astropy -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-foreign -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# contextlib2 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda[version='>=4.10.3'] -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-base -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-minqa -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-plyr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinx -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# html5lib -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-kernsmooth -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyter_core -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# yapf -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-base64enc -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pluggy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-gistr -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# isort -> python[version='>=3.6.1,<4.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# spyder -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# setuptools -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# multipledispatch -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-chron -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# applaunchservices -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-spatial -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-rcolorbrewer -> r-base=3.2.2 -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sip -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# future -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cytoolz -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-httpuv -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# itsdangerous -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# appnope -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numpydoc -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# anaconda==2020.07 -> tk==8.6.10=hb0a8c7a_0
# backports.tempfile -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-hexbin -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-stringi -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# wcwidth -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-munsell -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# brotlipy -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# urllib3 -> python[version='>=3.6,<4.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# filelock -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports.shutil_get_terminal_size -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl-service -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-essentials -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyterlab -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ujson -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tblib -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# libcurl -> krb5[version='>=1.17.1,<1.18.0a0'] -> tk[version='>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# rtree -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-xtable -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-assertthat -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ipywidgets -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# kiwisolver -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prometheus_client -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyopenssl -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scipy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pkginfo -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mccabe -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# py-lief -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pbdzmq -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# xlwt -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rmarkdown -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pillow -> python[version='>=3.6,<3.7.0a0'] -> tk=8.6
# r-boot -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# dask-core -> python[version='>=3.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mpmath -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prompt_toolkit -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-codetools -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# snowballstemmer -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# fastcache -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pandocfilters -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# requests -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-uuid -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-caret -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyflakes -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-colorspace -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# toolz -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-sparsem -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pep8 -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numba -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-dbi -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# idna -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# fsspec -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-matrixmodels -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-reshape2 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# qtpy -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# path -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# anaconda-client -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cycler -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-repr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pylint -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-gtable -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# xlsxwriter -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# atomicwrites -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# py -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rpart -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# attrs -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scikit-learn -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-crayon -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-shiny -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mock -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-irkernel -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# krb5 -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-dplyr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-formatr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pycodestyle -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-maps -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# flask -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-recommended -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytz -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-glmnet -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-class -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-catools -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# matplotlib -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-lme4 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mistune -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pygments -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# autopep8 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-websupport -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python.app -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# llvmlite -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zipp -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# regex -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# watchdog -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backcall -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# xlrd -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# argh -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-tidyr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-evaluate -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# markupsafe -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-openssl -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-mime -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# wrapt -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pytables -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pycosat -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# locket -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zope.event -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# importlib-metadata -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-magrittr -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pryr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-knitr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ptyprocess -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# simplegeneric -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zict -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# packaging -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# lazy-object-proxy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# appscript -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# beautifulsoup4 -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyodbc -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# glob2 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-foreach -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# toml -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda-verify -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# anaconda-navigator -> pillow -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# traitlets -> python[version='>=3.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pywavelets -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# imageio -> pillow -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# intervaltree -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# typing_extensions -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scikit-image -> pillow[version='>=4.3.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda-package-handling -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# threadpoolctl -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# testpath -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# werkzeug -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# patsy -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-quantmod -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyzmq -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports.functools_lru_cache -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# statsmodels -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sortedcollections -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bitarray -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyyaml -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pbkrtest -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ply -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-digest -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-htmltools -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pexpect -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-dateutil -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sortedcontainers -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# greenlet -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jsonschema -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bkcharts -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pickleshare -> python[version='>=3'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pathlib2 -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-nnet -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# more-itertools -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# qtawesome -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-ttr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# openpyxl -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# six -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pathtools -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda-build -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# docutils -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# clyent -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports.weakref -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pycparser -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# xlwings -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bleach -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pytest -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cython -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pydot -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-libarchive-c -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# click -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# send2trash -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-ggplot2 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# anaconda-project -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-nlme -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipython_genutils -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cloudpickle -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# seaborn -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# wurlitzer -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-data.table -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-rcpp -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# mkl_random -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python=3.8 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# soupsieve -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# boto -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# asn1crypto -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# psutil -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-r6 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# msgpack-python -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-dichromat -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-curl -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-httr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# chardet -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# decorator -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# flake8 -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# keyring -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyparsing -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# gmpy2 -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbformat -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cffi -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pydocstyle -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
#
# Package openssl conflicts for:
# ptyprocess -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# wrapt -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# libcurl -> libssh2[version='>=1.8.0,<2.0a0'] -> openssl[version='>=1.0.2m,<1.0.3a']
# sortedcollections -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# toml -> python[version='>=2.7'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# numpy-base -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# traitlets -> python[version='>=3.7'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# h5py -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2p,<1.0.3a']
# statsmodels -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# zope.event -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a']
# jupyter_client -> python[version='>=3.5'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# tblib -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# ...
# lxml -> libxslt[version='>=1.1.32,<2.0a0|>=1.1.33,<2.0a0|>=1.1.34,<2.0a0']
# anaconda==2020.07 -> libxslt==1.1.34=h83b36ba_0
# anaconda==2020.07 -> lxml==4.5.2=py37h63b7cb6_0 -> libxslt[version='>=1.1.34,<2.0a0']
#
# Package json5 conflicts for:
# anaconda==2020.07 -> json5==0.9.5=py_0
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> json5
# jupyterlab_server -> json5
# anaconda==2020.07 -> jupyterlab_server==1.2.0=py_0 -> json5
#
# Package r-tinytex conflicts for:
# r-gistr -> r-rmarkdown -> r-tinytex[version='>=0.11|>=0.3']
# r-rmarkdown -> r-tinytex[version='>=0.11|>=0.3']
# r-essentials -> r-rmarkdown[version='>=1.10'] -> r-tinytex[version='>=0.11|>=0.3']
# rstudio -> r-rmarkdown[version='>=1.6'] -> r-tinytex[version='>=0.11|>=0.3']
#
# Package diff-match-patch conflicts for:
# spyder -> diff-match-patch[version='>=20181111']
# anaconda==2020.07 -> diff-match-patch==20200713=py_0
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> diff-match-patch[version='>=20181111']
#
# Package spyder-kernels conflicts for:
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.10.1,<1.11.0|>=1.10.2,<1.11.0|>=2.0.1,<2.1.0|>=2.0.3,<2.1.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0']
# anaconda==2020.07 -> spyder-kernels==1.9.2[build='py38_0|py36_0|py37_0']
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> spyder-kernels[version='>=1.9.2,<1.10.0']
#
# Package bkcharts conflicts for:
# bokeh -> bkcharts[version='>=0.2']
# anaconda==2020.07 -> bkcharts==0.2[build='py38_0|py36_0|py37_0']
#
# Package jupyterlab_server conflicts for:
# jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0|>=1.1.5,<2.0.0|>=2.3,<3']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0|>=1.1.5,<2.0.0|>=2.3,<3']
# anaconda==2020.07 -> jupyterlab_server==1.2.0=py_0
# anaconda==2020.07 -> jupyterlab==2.1.5=py_0 -> jupyterlab_server[version='>=1.1.0,<2.0.0']
#
# Package pyobjc-framework-cocoa conflicts for:
# watchdog -> pyobjc-framework-cocoa[version='>=4.2.2']
# watchdog -> pyobjc-framework-fsevents[version='>=4.2.2'] -> pyobjc-framework-cocoa[version='>=6.1|>=6.2.1|>=6.2.2']
#
# Package pathtools conflicts for:
# spyder -> watchdog[version='>=0.10.3,<2.0.0'] -> pathtools[version='>=0.1.1']
# watchdog -> pathtools[version='>=0.1.1']
# anaconda==2020.07 -> pathtools==0.1.2=py_1
# anaconda==2020.07 -> watchdog==0.10.3=py37haf1e3a3_0 -> pathtools[version='>=0.1.1']
#
# Package r-colorspace conflicts for:
# r-munsell -> r-colorspace
# r-scales -> r-munsell[version='>=0.5'] -> r-colorspace
#
# Package anaconda-client conflicts for:
# anaconda-navigator -> anaconda-client[version='>=1.6|>=1.6.12|>=1.6.14']
# anaconda-navigator -> conda-repo-cli -> anaconda-client[version='>=1.7.2']
# anaconda==2020.07 -> anaconda-project==0.8.4=py_0 -> anaconda-client
# anaconda-project -> anaconda-client
# anaconda==2020.07 -> anaconda-client==1.7.2[build='py38_0|py36_0|py37_0']
#
# Package werkzeug conflicts for:
# anaconda==2020.07 -> werkzeug==1.0.1=py_0
# flask -> werkzeug[version='>=0.14|>=0.15|>=0.7,<1.0.0']
# anaconda==2020.07 -> flask==1.1.2=py_0 -> werkzeug[version='>=0.15']
#
# Package r-rcolorbrewer conflicts for:
# r-ggplot2 -> r-scales[version='>=0.5.0'] -> r-rcolorbrewer
# r-scales -> r-rcolorbrewer
# r-rbokeh -> r-scales -> r-rcolorbrewer
#
# Package ipywidgets conflicts for:
# anaconda==2020.07 -> jupyter==1.0.0=py37_7 -> ipywidgets
# _ipyw_jlab_nb_ext_conf -> ipywidgets
# r-irkernel -> jupyter -> ipywidgets
# anaconda==2020.07 -> ipywidgets==7.5.1=py_0
# jupyter -> ipywidgets
#
# Package r-gistr conflicts for:
# r-essentials -> r-rbokeh[version='>=0.5.0'] -> r-gistr
# r-rbokeh -> r-gistr
#
# Package astroid conflicts for:
# anaconda==2020.07 -> pylint==2.5.3=py37_0 -> astroid[version='>=2.4.0,<2.5']
# anaconda==2020.07 -> astroid==2.4.2[build='py38_0|py36_0|py37_0']
# pylint -> astroid[version='>=1.5.1|>=1.6,<2.0|>=2.0.0|>=2.2.0|>=2.3.0,<2.4|>=2.4.0,<2.5|>=2.4.0,<=2.5|>=2.5.8,<=2.7|>=2.6.2,<=2.7']
# spyder -> pylint[version='>=1.0'] -> astroid[version='>=1.5.1|>=1.6,<2.0|>=2.0.0|>=2.2.0|>=2.3.0,<2.4|>=2.4.0,<2.5|>=2.4.0,<=2.5|>=2.5.8,<=2.7|>=2.6.2,<=2.7']
# python-language-server -> pylint[version='>=2.5.0'] -> astroid[version='>=1.5.1|>=1.6,<2.0|>=2.0.0|>=2.2.0|>=2.3.0,<2.4|>=2.4.0,<2.5|>=2.4.0,<=2.5|>=2.5.8,<=2.7|>=2.6.2,<=2.7']
#
# Package jupyter_console conflicts for:
# anaconda==2020.07 -> jupyter==1.0.0=py37_7 -> jupyter_console
# anaconda==2020.07 -> jupyter_console==6.1.0=py_0
# jupyter -> jupyter_console
# r-irkernel -> jupyter -> jupyter_console
#
# Package dbus conflicts for:
# spyder -> pyqt[version='>=5.6,<5.13'] -> dbus[version='>=1.10.22,<2.0a0|>=1.12.2,<2.0a0|>=1.13.12,<2.0a0|>=1.13.2,<2.0a0']
# pyqt -> dbus[version='>=1.10.22,<2.0a0|>=1.12.2,<2.0a0|>=1.13.12,<2.0a0|>=1.13.2,<2.0a0']
# anaconda==2020.07 -> dbus==1.13.16=h18a8e69_0
# navigator-updater -> pyqt[version='>=5.6'] -> dbus[version='>=1.10.22,<2.0a0|>=1.12.2,<2.0a0|>=1.13.12,<2.0a0|>=1.13.2,<2.0a0']
# qtconsole -> pyqt -> dbus[version='>=1.10.22,<2.0a0|>=1.12.2,<2.0a0|>=1.13.12,<2.0a0|>=1.13.2,<2.0a0']
# anaconda-navigator -> pyqt[version='>=5.6,<6.0a0'] -> dbus[version='>=1.10.22,<2.0a0|>=1.12.2,<2.0a0|>=1.13.12,<2.0a0|>=1.13.2,<2.0a0']
# anaconda==2020.07 -> pyqt==5.9.2=py37h655552a_2 -> dbus[version='>=1.13.12,<2.0a0|>=1.13.2,<2.0a0']
#
# Package r-minqa conflicts for:
# r-lme4 -> r-minqa[version='>=1.1.15']
# r-car -> r-lme4 -> r-minqa[version='>=1.1.15']
# r-pbkrtest -> r-lme4[version='>=1.1.10'] -> r-minqa[version='>=1.1.15']
#
# Package r-bindrcpp conflicts for:
# r-dplyr -> r-bindrcpp[version='>=0.2|>=0.2.0.9000']
# r-tidyr -> r-dplyr[version='>=0.7.0'] -> r-bindrcpp[version='>=0.2|>=0.2.0.9000']
# r-essentials -> r-dplyr[version='>=0.7.6'] -> r-bindrcpp[version='>=0.2|>=0.2.0.9000']
# r-gistr -> r-dplyr -> r-bindrcpp[version='>=0.2|>=0.2.0.9000']
#
# Package pylint conflicts for:
# anaconda==2020.07 -> python-language-server==0.34.1=py37_0 -> pylint[version='>=1.0']
# spyder -> pylint[version='>=0.25|>=1.0']
# python-language-server -> pylint[version='>=2.5.0']
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> pylint[version='>=2.5.0']
# anaconda==2020.07 -> pylint==2.5.3[build='py38_0|py36_0|py37_0']
#
# Package r-kernsmooth conflicts for:
# r-essentials -> r-recommended[version='>=3.6.0'] -> r-kernsmooth
# r-recommended -> r-kernsmooth
#
# Package conda-package-handling conflicts for:
# conda[version='>=4.10.3'] -> conda-package-handling[version='>=1.3.0']
# conda-build -> conda[version='>=4.5'] -> conda-package-handling[version='>=1.0.4|>=1.3.0']
# conda-build -> conda-package-handling[version='>=1.1|>=1.3']
# conda-verify -> conda-package-handling[version='>=1.0.4|>=1.1']
#
# Package r-pryr conflicts for:
# r-essentials -> r-rbokeh[version='>=0.5.0'] -> r-pryr
# r-rbokeh -> r-pryr
#
# Package r-hexbin conflicts for:
# r-rbokeh -> r-hexbin
# r-essentials -> r-rbokeh[version='>=0.6.3'] -> r-hexbin
#
# Package glob2 conflicts for:
# conda-build -> glob2[version='>=0.6']
# anaconda==2020.07 -> glob2==0.7=py_0
#
# Package blosc conflicts for:
# anaconda==2020.07 -> blosc==1.19.0=hab81aa3_0
# anaconda==2020.07 -> pytables==3.6.1=py37h5bccee9_0 -> blosc[version='>=1.16.3,<2.0a0']
# pytables -> blosc[version='>=1.14.3,<2.0a0|>=1.14.4,<2.0a0|>=1.15.0,<2.0a0|>=1.16.3,<2.0a0|>=1.20.1,<2.0a0']
#
# Package r-iterators conflicts for:
# r-glmnet -> r-foreach -> r-iterators[version='>=1.0.10,<1.0.11.0a0']
# r-caret -> r-foreach -> r-iterators[version='>=1.0.10,<1.0.11.0a0']
# r-foreach -> r-iterators[version='>=1.0.10,<1.0.11.0a0']
#
# Package jupyterlab conflicts for:
# _ipyw_jlab_nb_ext_conf -> jupyterlab
# anaconda==2020.07 -> jupyterlab==2.1.5=py_0
#
# Package r-irkernel conflicts for:
# r-essentials -> r-irkernel[version='0.5|0.7|>=0.7.1|>=0.8.11|>=0.8.12|>=0.8.9|>=0.7|>=0.6.1',build=r3.3.1_2]
# rstudio -> r-essentials[version='>=3.4.3'] -> r-irkernel[version='0.5|0.7|>=0.7.1|>=0.8.11|>=0.8.12|>=0.8.9|>=0.7|>=0.6.1',build=r3.3.1_2]
#
# Package backports.weakref conflicts for:
# backports.tempfile -> backports.weakref
# conda-verify -> backports.tempfile -> backports.weakref
#
# Package r-rbokeh conflicts for:
# r-essentials -> r-rbokeh[version='0.2.2|>=0.4.2|>=0.5.0|>=0.6.3']
# rstudio -> r-essentials[version='>=3.4.3'] -> r-rbokeh[version='0.2.2|>=0.4.2|>=0.5.0|>=0.6.3']
#
# Package hdf5 conflicts for:
# anaconda==2020.07 -> hdf5==1.10.4=hfa1e0ec_0
# anaconda==2020.07 -> h5py==2.10.0=py37h3134771_0 -> hdf5[version='>=1.10.4,<1.10.5.0a0']
# pytables -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.20,<1.9.0a0|>=1.8.18,<1.8.19.0a0']
# h5py -> hdf5[version='>=1.10.1,<1.10.2.0a0|>=1.10.2,<1.10.3.0a0|>=1.10.4,<1.10.5.0a0|>=1.10.6,<1.10.7.0a0|>=1.8.20,<1.9.0a0|>=1.8.18,<1.8.19.0a0']
#
# Package keyring conflicts for:
# spyder -> keyring[version='>=17.0.0']
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> keyring
# anaconda==2020.07 -> keyring==21.2.1[build='py38_0|py36_0|py37_0']
#
# Package beautifulsoup4 conflicts for:
# anaconda==2020.07 -> beautifulsoup4==4.9.1[build='py38_0|py36_0|py37_0']
# soupsieve -> beautifulsoup4
# conda-build -> beautifulsoup4
#
# Package sphinx conflicts for:
# jedi -> numpydoc -> sphinx
# spyder -> sphinx[version='>=0.6.6']
# numpydoc -> sphinx
# anaconda==2020.07 -> sphinx==3.1.2=py_0
# anaconda==2020.07 -> numpydoc==1.1.0=py_0 -> sphinx[version='>=0.6.6']
#
# Package wrapt conflicts for:
# astroid -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
# anaconda==2020.07 -> astroid==2.4.2=py37_0 -> wrapt=1.11
# pylint -> astroid[version='>=2.6.2,<=2.7'] -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
# anaconda==2020.07 -> wrapt==1.11.2[build='py38h1de35cc_0|py37h1de35cc_0|py36h1de35cc_0']
#
# Package anyio conflicts for:
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> anyio[version='>=2.0.2']
# jupyterlab_server -> jupyter_server[version='>=1.1.0,<2.0.0'] -> anyio[version='>=2.0.2']
#
# Package regex conflicts for:
# anaconda==2020.07 -> regex==2020.6.8[build='py38haf1e3a3_0|py36haf1e3a3_0|py37haf1e3a3_0']
# anaconda==2020.07 -> nltk==3.5=py_0 -> regex
# nltk -> regex
#
# Package r-httpuv conflicts for:
# rstudio -> r-httpuv[version='>=1.3.3']
# rstudio -> r-shiny[version='>=1.0'] -> r-httpuv[version='>=1.3.5|>=1.4.3|>=1.5.0']
# r-essentials -> r-shiny[version='>=1.1.0'] -> r-httpuv[version='>=1.3.2|>=1.3.3|>=1.3.5|>=1.4.3|>=1.5.0']
# r-shiny -> r-httpuv[version='>=1.3.2|>=1.3.3|>=1.3.5|>=1.4.3|>=1.5.0']
#
# Package hypothesis conflicts for:
# attrs -> hypothesis
# astropy -> pytest-astropy -> hypothesis
# pytest -> attrs[version='>=17.2.0'] -> hypothesis
#
# Package r-labeling conflicts for:
# r-scales -> r-labeling
# r-ggplot2 -> r-scales[version='>=0.5.0'] -> r-labeling
# r-rbokeh -> r-scales -> r-labeling
#
# Package ripgrep conflicts for:
# conda-build -> ripgrep
# anaconda==2020.07 -> ripgrep==11.0.2=he32d670_0
#
# Package r-pbdzmq conflicts for:
# r-irkernel -> r-pbdzmq[version='>=0.2_1']
# r-essentials -> r-irkernel[version='>=0.8.12'] -> r-pbdzmq[version='>=0.2_1']
#
# Package r-recipes conflicts for:
# r-caret -> r-recipes[version='>=0.0.1|>=0.1.4']
# r-essentials -> r-caret[version='>=6.0-80'] -> r-recipes[version='>=0.0.1|>=0.1.4']
#
# Package dask-core conflicts for:
# scikit-image -> dask[version='>=0.5'] -> dask-core[version='0.15.2.*|0.15.3.*|0.15.4.*|0.16.0.*|0.16.1.*|0.17.0.*|0.17.1.*|0.17.2.*|0.17.3.*|0.17.4.*|0.17.5.*|0.18.0.*|0.18.1.*|0.18.2.*|0.19.0.*|0.19.1.*|0.19.2.*|0.19.3.*|0.19.4.*|0.20.0.*|0.20.1.*|0.20.2.*|1.0.0.*|1.1.1.*|1.1.2.*|1.1.3.*|1.1.4.*|1.1.5.*|1.2.0.*|1.2.2.*|2.0.0.*|2.1.0.*|2.10.0.*|2.10.1.*|2.11.0.*|2.12.0.*|2.13.0.*|2.14.0.*|2.15.0.*|2.16.0.*|2.17.0.*|2.17.2.*|2.18.1.*|2.19.0.*|2.20.0.*|2.22.0.*|2.23.0.*|2.24.0.*|2.25.0.*|2.26.0.*|2.27.0.*|2.29.0.*|2.30.0.*|2020.12.0.*|2021.1.0.*|2021.1.1.*|2021.2.0.*|2021.3.0.*|2021.3.1.*|2021.4.0.*|2021.4.1.*|2021.5.0.*|2021.5.1.*|2021.6.0.*|2021.6.1.*|2021.6.2.*|2.9.2.*|2.9.1.*|2.9.0.*|2.8.1.*|2.8.0.*|2.7.0.*|2.6.0.*|2.5.2.*|2.5.0.*|2.4.0.*|2.3.0.*|2.2.0.*']
# anaconda==2020.07 -> dask-core==2.20.0=py_0
# scikit-image -> dask-core[version='>=0.15|>=0.15.0|>=0.9.0']
# distributed -> dask-core[version='2021.5.0.*|2021.5.1.*|2021.6.0.*|2021.6.1.*|2021.6.2.*|>=2021.3.0|>=2020.12.0|>=2.9.0|>=2.7.0|>=2.5.2|>=2|>=0.18.0|>=0.17.0|>=0.16.0|>=0.15.2']
# anaconda==2020.07 -> dask==2.20.0=py_0 -> dask-core[version='2.20.0.*|>=2.9.0|>=0.15.0']
#
# Package watchdog conflicts for:
# spyder -> watchdog[version='>=0.10.3|>=0.10.3,<2.0.0']
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> watchdog
# anaconda==2020.07 -> watchdog==0.10.3[build='py38haf1e3a3_0|py36haf1e3a3_0|py37haf1e3a3_0']
#
# Package pbr conflicts for:
# mock -> pbr
# pytables -> mock -> pbr
#
# Package zope.interface conflicts for:
# gevent -> zope.interface
# attrs -> zope.interface
# pytest -> attrs[version='>=17.2.0'] -> zope.interface
# anaconda==2020.07 -> gevent==20.6.2=py37haf1e3a3_0 -> zope.interface
# prometheus_client -> twisted -> zope.interface[version='>=4.0.2|>=4.4.2']
# anaconda==2020.07 -> zope.interface==4.7.1[build='py38h1de35cc_0|py37h1de35cc_0|py36h1de35cc_0']
#
# Package r-formatr conflicts for:
# r-rmarkdown -> r-knitr[version='>=1.12'] -> r-formatr
# r-essentials -> r-formatr[version='>=1.4|>=1.5']
# rstudio -> r-essentials[version='>=3.4.3'] -> r-formatr[version='>=1.4|>=1.5']
# r-gistr -> r-knitr -> r-formatr
# r-knitr -> r-formatr
#
# Package rtree conflicts for:
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> rtree[version='>=0.8.3']
# spyder -> rtree[version='>=0.8.3|>=0.9.7']
# anaconda==2020.07 -> rtree==0.9.4[build='py38_1|py36_1|py37_1']
#
# Package pyrsistent conflicts for:
# anaconda==2020.07 -> pyrsistent==0.16.0[build='py38h1de35cc_0|py37h1de35cc_0|py36h1de35cc_0']
# jsonschema -> pyrsistent[version='>=0.14.0']
# spyder -> jsonschema[version='>=3.2.0'] -> pyrsistent[version='>=0.14.0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> pyrsistent[version='>=0.14.0']
# anaconda==2020.07 -> jsonschema==3.2.0=py37_0 -> pyrsistent[version='>=0.14.0']
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> pyrsistent[version='>=0.14.0']
#
# Package r-spatial conflicts for:
# r-essentials -> r-recommended[version='>=3.6.0'] -> r-spatial
# r-recommended -> r-spatial
#
# Package r-rpart conflicts for:
# r-essentials -> r-recommended[version='>=3.6.0'] -> r-rpart
# r-recommended -> r-rpart
#
# Package msgpack-python conflicts for:
# anaconda==2020.07 -> msgpack-python==1.0.0[build='py38h04f5b5a_1|py36h04f5b5a_1|py37h04f5b5a_1']
# anaconda==2020.07 -> distributed==2.20.0=py37_0 -> msgpack-python[version='>=0.6.0']
# distributed -> msgpack-python[version='>=0.6.0']
#
# Package r-uuid conflicts for:
# r-essentials -> r-irkernel[version='>=0.8.12'] -> r-uuid
# r-irkernel -> r-uuid
#
# Package dask conflicts for:
# anaconda==2020.07 -> dask==2.20.0=py_0
# scikit-image -> dask[version='>=0.5']
#
# Package r-pbkrtest conflicts for:
# r-caret -> r-car -> r-pbkrtest[version='>=0.3_2|>=0.4_4']
# r-car -> r-pbkrtest[version='>=0.3_2|>=0.4_4']
#
# Package statsmodels conflicts for:
# anaconda==2020.07 -> statsmodels==0.11.1[build='py38haf1e3a3_0|py36haf1e3a3_0|py37haf1e3a3_0']
# seaborn -> statsmodels[version='>=0.5.0']
#
# Package twisted conflicts for:
# notebook -> prometheus_client -> twisted
# prometheus_client -> twisted
#
# Package cython conflicts for:
# nltk -> gensim -> cython==0.29.23
# anaconda==2020.07 -> cython==0.29.21[build='py37hb1e8313_0|py36hb1e8313_0|py38hb1e8313_0']
#
# Package html5lib conflicts for:
# nbconvert -> bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
# anaconda==2020.07 -> html5lib==1.1=py_0
# bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
#
# Package r-survival conflicts for:
# r-essentials -> r-recommended[version='>=3.6.0'] -> r-survival
# r-recommended -> r-survival
#
# Package conda-pack conflicts for:
# anaconda-project -> conda-pack
# anaconda-navigator -> anaconda-project -> conda-pack
#
# Package r-rcppeigen conflicts for:
# r-pbkrtest -> r-lme4[version='>=1.1.10'] -> r-rcppeigen
# r-lme4 -> r-rcppeigen
# r-car -> r-lme4 -> r-rcppeigen
#
# Package selectors2 conflicts for:
# spyder-kernels -> wurlitzer[version='>=1.0.3'] -> selectors2
# wurlitzer -> selectors2
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install graphviz
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                      -failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - anaconda==2020.07 -> python[version='3.6.10|3.7.7|3.8.3',build='hf48f09d_2|hf48f09d_4|h26836e1_2']
#   - atomicwrites -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - attrs -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - autopep8 -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - backports -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - backports.functools_lru_cache -> python[version='>=2.7,<2.8.0a0']
#   - bleach -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - brotlipy -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - colorama -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda-verify -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - conda[version='>=4.10.3'] -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - contextlib2 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - defusedxml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - filelock -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - flake8 -> python[version='>=3.9,<3.10.0a0']
#   - flask -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - glob2 -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - h5py -> python[version='<3']
#   - html5lib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.9,<3.10.0a0']
#   - imagesize -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - ipywidgets -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - isort -> python[version='>=3.9,<3.10.0a0']
#   - jdcal -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - matplotlib-base -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - mock -> python[version='>=3.9,<3.10.0a0']
#   - more-itertools -> python[version='>=3.9,<3.10.0a0']
#   - nose -> python[version='>=3.9,<3.10.0a0']
#   - numba -> python=3.4
#   - olefile -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - path -> python[version='>=2.7,<2.8.0a0']
#   - pickleshare -> python[version='>=3.9,<3.10.0a0']
#   - prometheus_client -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - pycparser -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0']
#   - pyflakes -> python[version='>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.9,<3.10.0a0']
#   - pyparsing -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pyrsistent -> python[version='>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pytz -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - qtpy -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - rope -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - snowballstemmer -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - sortedcollections -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - sphinxcontrib-websupport -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - tblib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - typing_extensions -> python[version='>=3.9,<3.10.0a0']
#   - watchdog -> python[version='>=3.5,<3.6.0a0']
#   - werkzeug -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - wheel -> python[version='>=3.9,<3.10.0a0']
#   - wurlitzer -> python[version='<3.4']
#   - xlrd -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - xlsxwriter -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - xmltodict -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - yapf -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - zict -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - zope.event -> python[version='>=3.5,<3.6.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package functools32 conflicts for:
# bokeh -> matplotlib -> functools32
# python-language-server -> flake8 -> functools32
# matplotlib -> functools32
# scikit-image -> matplotlib[version='>=2.0.0'] -> functools32
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> functools32
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> functools32
# seaborn -> matplotlib[version='>=2.1.2'] -> functools32
# jsonschema -> functools32
# flake8 -> functools32
# nltk -> matplotlib -> functools32
# spyder -> jsonschema[version='>=3.2.0'] -> functools32
#
# Package wcwidth conflicts for:
# anaconda==2020.07 -> prompt-toolkit==3.0.5=py_0 -> wcwidth
# prompt-toolkit -> wcwidth
# anaconda==2020.07 -> wcwidth==0.2.5=py_0
# pytest -> wcwidth
# ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0'] -> wcwidth
# astropy -> pytest -> wcwidth
# prompt_toolkit -> wcwidth
#
# Package tk conflicts for:
# py -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# importlib_metadata -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# click -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sympy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# applaunchservices -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipython_genutils -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# conda-verify -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pywavelets -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter_core -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pexpect -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# path.py -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-kernsmooth -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-recommended -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# conda[version='>=4.10.3'] -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-shiny -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# diff-match-patch -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# alabaster -> python[version='>=2.7,<2.8.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.10,<8.7.0a0']
# anaconda==2020.07 -> tk==8.6.10=hb0a8c7a_0
# mkl_random -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# json5 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numpydoc -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-digest -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# attrs -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# clyent -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# anaconda-client -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-htmlhelp -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-language-server -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# wcwidth -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# dask-core -> python[version='>=3.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# setuptools -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-stringi -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# idna -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports.functools_lru_cache -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rcolorbrewer -> r-base=3.2.2 -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# snowballstemmer -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# threadpoolctl -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-jsonrpc-server -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pep8 -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tqdm -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pycurl -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# requests -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mistune -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zipp -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pluggy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# colorama -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tblib -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# toolz -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# path -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-tibble -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# xlwt -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-spatial -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# backports.shutil_get_terminal_size -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# contextlib2 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-websupport -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-htmlwidgets -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pycosat -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# msgpack-python -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# rtree -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-essentials -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-maps -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-glmnet -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-bitops -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-openssl -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ply -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# flake8 -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sqlalchemy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-nloptr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-memoise -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-repr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# lazy-object-proxy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prometheus_client -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# imageio -> pillow -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# flask -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# xmltodict -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-matrixmodels -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-gistr -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# soupsieve -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# gevent -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-dateutil -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rbokeh -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# conda-package-handling -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# regex -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scipy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mock -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rcppeigen -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jdcal -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-munsell -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-htmltools -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-labeling -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# sortedcollections -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# greenlet -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-curl -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# appnope -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bleach -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zope -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nltk -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# importlib-metadata -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-mass -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# anaconda==2020.07 -> pillow==7.2.0=py37ha54b6ba_0 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pytz -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-caret -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-boot -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyopenssl -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mpmath -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# asn1crypto -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# future -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# yapf -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-codetools -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# joblib -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-irkernel -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ptyprocess -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# kiwisolver -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-yaml -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-colorspace -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# boto -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# curl -> krb5[version='>=1.17.1,<1.18.0a0'] -> tk[version='>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# backports.weakref -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-nlme -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# cloudpickle -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-car -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-irdisplay -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-ggplot2 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyodbc -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-scales -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# argh -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# unicodecsv -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-httr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# scikit-image -> pillow[version='>=4.3.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyyaml -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# anaconda-navigator -> pillow -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sip -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipywidgets -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# docutils -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# llvmlite -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# distributed -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pydocstyle -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jinja2 -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-randomforest -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# networkx -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-iterators -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jupyterlab_server -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numpy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# spyder -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-uuid -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pylint -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-cluster -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# python.app -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-hexbin -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# toml -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# et_xmlfile -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-foreign -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# qtpy -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pip -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# defusedxml -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pbkrtest -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pyparsing -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pygments -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-magrittr -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-foreach -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# conda-build -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nose -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# decorator -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-r6 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# heapdict -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-zoo -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-quantreg -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-evaluate -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# cffi -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# simplegeneric -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cytoolz -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# multipledispatch -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# qdarkstyle -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# xlwings -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyflakes -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mccabe -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-class -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# dask -> python[version='>=3.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-data.table -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-matrix -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# appscript -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pillow -> python[version='>=3.6,<3.7.0a0'] -> tk=8.6
# numpy-base -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pathtools -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ujson -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports.tempfile -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# openpyxl -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pytables -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-survival -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# watchdog -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# fsspec -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-xtable -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-reshape2 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# typing_extensions -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# six -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyzmq -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-markdown -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# werkzeug -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numba -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# intervaltree -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-mgcv -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-crayon -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# bitarray -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pkginfo -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cython -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-catools -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pycodestyle -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rcpp -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-ttr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# locket -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# anaconda-project -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter_client -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# patsy -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bkcharts -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyterlab -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pycparser -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pickleshare -> python[version='>=3'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rmarkdown -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# xlrd -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jsonschema -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# statsmodels -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-lme4 -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pathlib2 -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinx -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# keyring -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-mime -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# pandocfilters -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ruamel_yaml -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pytest -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# testpath -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-jsonlite -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# seaborn -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# wurlitzer -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python=3.8 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# qtconsole -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# krb5 -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-lattice -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# imagesize -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# markupsafe -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sortedcontainers -> python[version='>=2.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# py-lief -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pbdzmq -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-highr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# more-itertools -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl-service -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-pryr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-quantmod -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# zict -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-tidyr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# astroid -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# atomicwrites -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# libcurl -> krb5[version='>=1.17.1,<1.18.0a0'] -> tk[version='>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# certifi -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prompt_toolkit -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# lxml -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# parso -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# fastcache -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# itsdangerous -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-stringr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# astropy -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-assertthat -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# scikit-learn -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backcall -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-dichromat -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# rope -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-formatr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# cycler -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipython -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# partd -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# qtawesome -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# html5lib -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-gtable -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# send2trash -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-xts -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# wrapt -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# singledispatch -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# traitlets -> python[version='>=3.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# brotlipy -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-rpart -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# beautifulsoup4 -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-base -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-knitr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-dbi -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-bh -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# gmpy2 -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# spyder-kernels -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-lazyeval -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-chron -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# isort -> python[version='>=3.6.1,<4.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-minqa -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# nbformat -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zope.event -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# filelock -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-plyr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# wheel -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pandas -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-libarchive-c -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# autopep8 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# psutil -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# packaging -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# chardet -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# urllib3 -> python[version='>=3.6,<4.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# xlsxwriter -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# h5py -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-base64enc -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-httpuv -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# babel -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-sparsem -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# r-nnet -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# glob2 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# r-dplyr -> r-base[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
#
# Package libiconv conflicts for:
# r-digest -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-class -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-evaluate -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-dplyr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-matrix -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# anaconda==2020.07 -> libiconv==1.16=h1de35cc_0
# r-survival -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-shiny -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-base64enc -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-recommended -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# python-libarchive-c -> libarchive -> libiconv[version='>=1.15,<2.0a0']
# r-ttr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-quantreg -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-lme4 -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-data.table -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-zoo -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-crayon -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-nloptr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-glmnet -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# conda-build -> libarchive -> libiconv[version='>=1.15,<2.0a0']
# r-repr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-irdisplay -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-tidyr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# libxml2 -> libiconv[version='>=1.15,<2.0a0|>=1.16,<2.0a0']
# dbus -> glib -> libiconv[version='>=1.15,<2.0a0|>=1.16,<2.0a0']
# libarchive -> libiconv[version='>=1.15,<2.0a0']
# r-assertthat -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-quantmod -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-catools -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-gtable -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-dbi -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-highr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-codetools -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-nlme -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-base -> libiconv[version='>=1.15,<2.0a0']
# r-scales -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-lazyeval -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# conda-package-handling -> libarchive[version='>=3.3.3'] -> libiconv[version='>=1.15,<2.0a0']
# r-pbkrtest -> r-base[version='>=3.5.1,<3.5.2.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# libarchive -> libxml2[version='>=2.9.9,<2.10.0a0'] -> libiconv[version='>=1.16,<2.0a0']
# r-pbdzmq -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-httr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-randomforest -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# graphviz -> fontconfig[version='>=2.13.0,<3.0a0'] -> libiconv[version='>=1.15,<2.0a0|>=1.16,<2.0a0']
# r-base -> libxml2[version='>=2.9.9,<2.10.0a0'] -> libiconv[version='>=1.16,<2.0a0']
# r-formatr -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# r-nnet -> r-base[version='>=3.6,<3.7.0a0'] -> libiconv[version='>=1.15,<2.0a0']
# ...
#
# Package r-backports conflicts for:
# r-essentials -> r-broom[version='>=0.5.0'] -> r-backports
# r-rmarkdown -> r-rprojroot -> r-backports
# rstudio -> r-rprojroot[version='>=1.0'] -> r-backports
#
# Package r-xfun conflicts for:
# rstudio -> r-knitr[version='>=1.14'] -> r-xfun
# r-rmarkdown -> r-knitr[version='>=1.22'] -> r-xfun[version='>=0.3|>=0.5']
# r-gistr -> r-knitr -> r-xfun
# r-knitr -> r-xfun
#
# Package r-ttr conflicts for:
# r-essentials -> r-quantmod[version='>=0.4_13'] -> r-ttr[version='>=0.2']
# r-quantmod -> r-ttr[version='>=0.2']
#
# Package tblib conflicts for:
# dask -> distributed=2021.6.2 -> tblib[version='>=1.6.0']
# anaconda==2020.07 -> distributed==2.20.0=py37_0 -> tblib[version='>=1.6.0']
# anaconda==2020.07 -> tblib==1.6.0=py_0
# distributed -> tblib[version='>=1.6.0']
#
# Package jaraco.itertools conflicts for:
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# importlib_metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# zipp -> jaraco.itertools
#
# Package iniconfig conflicts for:
# astropy -> pytest -> iniconfig
# pytest -> iniconfig
#
# Package r-rmarkdown conflicts for:
# rstudio -> r-essentials[version='>=3.4.3'] -> r-rmarkdown[version='0.8.1|>=0.9.6|>=1.10|>=1.9|>=1.8|>=1.5|>=1.3|>=1.2']
# r-gistr -> r-rmarkdown
# r-rbokeh -> r-gistr -> r-rmarkdown
# rstudio -> r-rmarkdown[version='>=1.6']
# r-essentials -> r-rmarkdown[version='0.8.1|>=0.9.6|>=1.10|>=1.9|>=1.8|>=1.6|>=1.5|>=1.3|>=1.2']
#
# Package libllvm10 conflicts for:
# numba -> llvmlite[version='>=0.36.0,<0.37.0a0'] -> libllvm10[version='>=10.0.1,<10.1.0a0']
# llvmlite -> libllvm10[version='>=10.0.1,<10.1.0a0']
#
# Package colorama conflicts for:
# sphinx -> colorama[version='>=0.3.5']
# numpydoc -> sphinx -> colorama[version='>=0.3.5']
# spyder -> sphinx[version='>=0.6.6'] -> colorama[version='>=0.3.5']
# anaconda==2020.07 -> colorama==0.4.3=py_0
#
# Package pympler conflicts for:
# pytest -> attrs[version='>=17.2.0'] -> pympler
# attrs -> pympler
# spyder -> pympler
#
# Package python-jsonrpc-server conflicts for:
# anaconda==2020.07 -> python-jsonrpc-server==0.3.4=py_1
# spyder -> python-language-server[version='>=0.36.2,<1.0.0'] -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
# python-language-server -> python-jsonrpc-server[version='>=0.3.2|>=0.4.0']
# anaconda==2020.07 -> python-language-server==0.34.1=py37_0 -> python-jsonrpc-server[version='>=0.3.2']
#
# Package defusedxml conflicts for:
# jupyter -> nbconvert -> defusedxml
# notebook -> nbconvert -> defusedxml
# anaconda==2020.07 -> defusedxml==0.6.0=py_0
# anaconda==2020.07 -> nbconvert==5.6.1=py37_0 -> defusedxml
# nbconvert -> defusedxml
# spyder -> nbconvert[version='>=4.0'] -> defusedxml
#
# Package nbclient conflicts for:
# nbconvert -> nbclient[version='>=0.5.0,<0.6.0']
# spyder -> nbconvert[version='>=4.0'] -> nbclient[version='>=0.5.0,<0.6.0']
# notebook -> nbconvert -> nbclient[version='>=0.5.0,<0.6.0']
# jupyter -> nbconvert -> nbclient[version='>=0.5.0,<0.6.0']
#
# Package libllvm9 conflicts for:
# anaconda==2020.07 -> libllvm9==9.0.1=h21ff451_1
# anaconda==2020.07 -> llvmlite==0.33.0=py37ha11be7d_1 -> libllvm9==9.0.1[build=*_1]
# numba -> llvmlite[version='>=0.33.0',build=*_1] -> libllvm9==9.0.1[build=*_1]
# llvmlite -> libllvm9==9.0.1[build=*_1]
#
# Package gmpy2 conflicts for:
# anaconda==2020.07 -> sympy==1.6.1=py37_0 -> gmpy2[version='>=2.0.8']
# anaconda==2020.07 -> gmpy2==2.0.8[build='py38h6ef4df4_3|py37h6ef4df4_2|py36h6ef4df4_2']
# sympy -> gmpy2[version='>=2.0.8']
#
# Package r-bh conflicts for:
# r-shiny -> r-httpuv[version='>=1.5.0'] -> r-bh
# r-dplyr -> r-bh[version='>=1.58.0_1']
# r-essentials -> r-dplyr[version='>=0.7.6'] -> r-bh[version='>=1.58.0_1']
# r-gistr -> r-dplyr -> r-bh[version='>=1.58.0_1']
# r-tidyr -> r-dplyr[version='>=0.7.0'] -> r-bh[version='>=1.58.0_1']
# rstudio -> r-haven[version='>=0.2.0'] -> r-bh
# r-httpuv -> r-bh
#
# Package qdarkstyle conflicts for:
# anaconda==2020.07 -> qdarkstyle==2.8.1=py_0
# spyder -> qdarkstyle[version='3.0.2.*|>=2.8,<3.0|>=2.8|>=2.7']
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> qdarkstyle[version='>=2.8']
#
# Package r-dbi conflicts for:
# r-tidyr -> r-dplyr[version='>=0.4'] -> r-dbi[version='>=0.3|>=0.4.1']
# r-dplyr -> r-dbi[version='>=0.3|>=0.4.1']
# r-essentials -> r-dbi[version='>=0.5_1|>=0.6_1|>=0.7|>=1.0.0']
# rstudio -> r-odbc[version='>=1.1.1'] -> r-dbi[version='>=0.3.0|>=1.0.0|>=0.6_1|>=0.6|>=0.7|>=0.5_1']
# r-gistr -> r-dplyr -> r-dbi[version='>=0.3|>=0.4.1']
# r-essentials -> r-dplyr[version='>=0.5.0'] -> r-dbi[version='>=0.3|>=0.4.1']
#
# Package jupyterlab conflicts for:
# _ipyw_jlab_nb_ext_conf -> jupyterlab
# anaconda==2020.07 -> jupyterlab==2.1.5=py_0
#
# Package pyobjc-framework-fsevents conflicts for:
# spyder -> watchdog -> pyobjc-framework-fsevents[version='>=4.2.2']
# watchdog -> pyobjc-framework-fsevents[version='>=4.2.2']
#
# Package py-lief conflicts for:
# anaconda==2020.07 -> py-lief==0.10.1[build='py38haf313ee_0|py36haf313ee_0|py37haf313ee_0']
# conda-build -> py-lief
#
# Package tbb4py conflicts for:
# numpy-base -> tbb4py
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
# numpy -> numpy-base==1.15.4=py36h8a80b8c_0 -> tbb4py
#
# Package cryptography-vectors conflicts for:
# cryptography -> cryptography-vectors=2.3
# urllib3 -> cryptography[version='>=1.3.4'] -> cryptography-vectors=2.3
# pyopenssl -> cryptography[version='>=2.2.1'] -> cryptography-vectors=2.3
#
# Package brotlipy conflicts for:
# anaconda==2020.07 -> brotlipy==0.7.0[build='py36haf1e3a3_1000|py37haf1e3a3_1000|py38haf1e3a3_1000']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
# anaconda==2020.07 -> urllib3==1.25.9=py_0 -> brotlipy[version='>=0.6.0']
# urllib3 -> brotlipy[version='>=0.6.0']
#
# Package pkginfo conflicts for:
# anaconda==2020.07 -> pkginfo==1.5.0.1[build='py38_0|py36_0|py37_0']
# conda-build -> pkginfo
#
# Package lcms2 conflicts for:
# bokeh -> pillow[version='>=7.1.0'] -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# anaconda==2020.07 -> lcms2==2.11=h92f6f08_0
# anaconda-navigator -> pillow -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# imageio -> pillow -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# pillow -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# scikit-image -> pillow[version='>=4.3.0'] -> lcms2[version='>=2.11,<3.0a0|>=2.12,<3.0a0']
# anaconda==2020.07 -> pillow==7.2.0=py37ha54b6ba_0 -> lcms2[version='>=2.11,<3.0a0']
#
# Package r-survival conflicts for:
# r-recommended -> r-survival
# r-essentials -> r-recommended[version='>=3.6.0'] -> r-survival
#
# Package r-data.table conflicts for:
# r-essentials -> r-data.table[version='1.9.6|>=1.10.0|>=1.10.4|>=1.10.4_3|>=1.11.4|>=1.9.6']
# r-caret -> r-modelmetrics[version='>=1.1.0'] -> r-data.table
# rstudio -> r-essentials[version='>=3.4.3'] -> r-data.table[version='1.9.6|>=1.10.0|>=1.10.4|>=1.10.4_3|>=1.11.4|>=1.9.6']
# r-car -> r-rio -> r-data.table[version='>=1.9.8']
#
# Package r-recommended conflicts for:
# rstudio -> r-essentials[version='>=3.4.3'] -> r-recommended[version='>=3.3.1|>=3.3.2|>=3.4.1|>=3.4.2|>=3.4.3|>=3.5.0|>=3.5.1|>=3.6.0']
# r-essentials -> r-recommended[version='>=3.3.1|>=3.3.2|>=3.4.1|>=3.4.2|>=3.4.3|>=3.5.0|>=3.5.1|>=3.6.0']
#
# Package hypothesis conflicts for:
# astropy -> pytest-astropy -> hypothesis
# pytest -> attrs[version='>=17.2.0'] -> hypothesis
# attrs -> hypothesis
#
# Package scandir conflicts for:
# importlib_metadata -> pathlib2 -> scandir
# testpath -> pathlib2 -> scandir
# conda-build -> scandir
# pickleshare -> pathlib2 -> scandir
# pytest -> pathlib2[version='>=2.2.0'] -> scandir
# ipython -> pathlib2 -> scandir
# pathlib2 -> scandir
#
# Package r-recipes conflicts for:
# r-caret -> r-recipes[version='>=0.0.1|>=0.1.4']
# r-essentials -> r-caret[version='>=6.0-80'] -> r-recipes[version='>=0.0.1|>=0.1.4']
#
# Package pathtools conflicts for:
# spyder -> watchdog[version='>=0.10.3,<2.0.0'] -> pathtools[version='>=0.1.1']
# anaconda==2020.07 -> pathtools==0.1.2=py_1
# watchdog -> pathtools[version='>=0.1.1']
# anaconda==2020.07 -> watchdog==0.10.3=py37haf1e3a3_0 -> pathtools[version='>=0.1.1']
#
# Package llvmlite conflicts for:
# anaconda==2020.07 -> numba==0.50.1=py37h959d312_1 -> llvmlite[version='>=0.33.0|>=0.33.0,<0.34.0a0',build=*_1]
# anaconda==2020.07 -> llvmlite==0.33.0[build='py36ha11be7d_1|py37ha11be7d_1|py38ha11be7d_1']
# numba -> llvmlite[version='0.20.*|0.21.*|0.22.*|0.23.*|0.24.*|>=0.25.0,<0.26.0a0|>=0.26.0,<0.27.0a0|>=0.27.0,<0.28.0a0|>=0.28.0,<0.29.0a0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.31.0|>=0.32.0,<0.33.0a0|>=0.32.0|>=0.32.1,<0.33.0a0|>=0.32.1|>=0.33.0|>=0.33.0,<0.34.0a0|>=0.33.0|>=0.34.0,<0.35|>=0.35.0,<0.36.0a0|>=0.36.0,<0.37.0a0',build=*_1]
#
# Package bokeh conflicts for:
# anaconda==2020.07 -> bokeh==2.1.1[build='py38_0|py36_0|py37_0']
# anaconda==2020.07 -> dask==2.20.0=py_0 -> bokeh[version='>=1.0.0,!=2.0.0']
# dask -> bokeh[version='>=0.13.0|>=1.0.0|>=1.0.0,!=2.0.0']
# scikit-image -> dask[version='>=0.5'] -> bokeh[version='>=0.13.0|>=1.0.0|>=1.0.0,!=2.0.0']
#
# Package patsy conflicts for:
# anaconda==2020.07 -> statsmodels==0.11.1=py37haf1e3a3_0 -> patsy[version='>=0.5.1']
# anaconda==2020.07 -> patsy==0.5.1[build='py38_0|py36_0|py37_0']
# seaborn -> patsy
# statsmodels -> patsy[version='>=0.4.0|>=0.5.1']
# seaborn -> statsmodels[version='>=0.5.0'] -> patsy[version='>=0.4.0|>=0.5.1']
#
# Package sphinxcontrib-qthelp conflicts for:
# anaconda==2020.07 -> sphinx==3.1.2=py_0 -> sphinxcontrib-qthelp
# sphinx -> sphinxcontrib-qthelp
# anaconda==2020.07 -> sphinxcontrib-qthelp==1.0.3=py_0
# numpydoc -> sphinx -> sphinxcontrib-qthelp
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-qthelp
#
# Package pytest conflicts for:
# anaconda==2020.07 -> pytest==5.4.3[build='py38_0|py36_0|py37_0']
# astropy -> pytest[version='<3.7|<4']
# astropy -> pytest-astropy -> pytest[version='>=3.1|>=3.1.0']
#
# Package r-askpass conflicts for:
# r-openssl -> r-askpass
# r-httr -> r-openssl[version='>=0.8'] -> r-askpass
#
# Package r-car conflicts for:
# r-caret -> r-car
# r-essentials -> r-caret[version='>=6.0_76'] -> r-car
#
# Package itsdangerous conflicts for:
# anaconda==2020.07 -> flask==1.1.2=py_0 -> itsdangerous[version='>=0.24']
# anaconda==2020.07 -> itsdangerous==1.1.0[build='py36_0|py37_0|py_0']
# flask -> itsdangerous[version='>=0.21|>=0.24']
#
# Package cython conflicts for:
# nltk -> gensim -> cython==0.29.23
# anaconda==2020.07 -> cython==0.29.21[build='py38hb1e8313_0|py36hb1e8313_0|py37hb1e8313_0']
#
# Package beautifulsoup4 conflicts for:
# anaconda==2020.07 -> beautifulsoup4==4.9.1[build='py38_0|py36_0|py37_0']
# conda-build -> beautifulsoup4
# soupsieve -> beautifulsoup4
#
# Package r-maps conflicts for:
# r-essentials -> r-rbokeh[version='>=0.6.3'] -> r-maps
# r-rbokeh -> r-maps
#
# Package r-caret conflicts for:
# r-essentials -> r-caret[version='6.0_62|>=6.0-80|>=6.0_79|>=6.0_78|>=6.0_77|>=6.0_76|>=6.0_73|>=6.0_70']
# rstudio -> r-essentials[version='>=3.4.3'] -> r-caret[version='6.0_62|>=6.0-80|>=6.0_79|>=6.0_78|>=6.0_77|>=6.0_76|>=6.0_73|>=6.0_70']
#
# Package r-uuid conflicts for:
# r-irkernel -> r-uuid
# r-essentials -> r-irkernel[version='>=0.8.12'] -> r-uuid
#
# Package pyobjc-framework-cocoa conflicts for:
# watchdog -> pyobjc-framework-fsevents[version='>=4.2.2'] -> pyobjc-framework-cocoa[version='>=6.1|>=6.2.1|>=6.2.2']
# watchdog -> pyobjc-framework-cocoa[version='>=4.2.2']
#
# Package typing-extensions conflicts for:
# pylint -> astroid[version='>=2.6.2,<=2.7'] -> typing-extensions[version='>=3.7.4']
# astroid -> typing-extensions[version='>=3.7.4']
#
# Package statsmodels conflicts for:
# seaborn -> statsmodels[version='>=0.5.0']
# anaconda==2020.07 -> statsmodels==0.11.1[build='py38haf1e3a3_0|py37haf1e3a3_0|py36haf1e3a3_0']
#
# Package backports.weakref conflicts for:
# backports.tempfile -> backports.weakref
# conda-verify -> backports.tempfile -> backports.weakref
#
# Package glob2 conflicts for:
# anaconda==2020.07 -> glob2==0.7=py_0
# conda-build -> glob2[version='>=0.6']
#
# Package r-rjsonio conflicts for:
# r-essentials -> r-rbokeh==0.2.2 -> r-rjsonio
# r-rbokeh -> r-rjsonio
# r-shiny -> r-rjsonio
# rstudio -> r-rsconnect[version='>=0.8.5'] -> r-rjsonio
# rstudio -> r-rjsonio[version='>=1.0|>=1.3']
#
# Package webencodings conflicts for:
# bleach -> webencodings
# nbconvert -> bleach -> webencodings
# anaconda==2020.07 -> webencodings==0.5.1[build='py36_1|py37_1|py38_1']
# anaconda==2020.07 -> bleach==3.1.5=py_0 -> webencodings
# html5lib -> webencodings
#
# Package rtree conflicts for:
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> rtree[version='>=0.8.3']
# anaconda==2020.07 -> rtree==0.9.4[build='py36_1|py37_1|py38_1']
# spyder -> rtree[version='>=0.8.3|>=0.9.7']
#
# Package r-hexbin conflicts for:
# r-rbokeh -> r-hexbin
# r-essentials -> r-rbokeh[version='>=0.6.3'] -> r-hexbin
#
# Package python-language-server conflicts for:
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> python-language-server[version='>=0.34.0,<1.0.0']
# spyder -> python-language-server[version='>=0.31.2,<0.32.0|>=0.31.9,<0.32.0|>=0.34.0,<1.0.0|>=0.36.1,<1.0.0|>=0.36.2,<1.0.0']
# anaconda==2020.07 -> python-language-server==0.34.1[build='py38_0|py36_0|py37_0']
# spyder -> pyls-black[version='>=0.4.6'] -> python-language-server[version='>=0.36.2']
#
# Package funcsigs conflicts for:
# mock -> funcsigs
# pytest -> funcsigs[version='>=1.0']
# astropy -> pytest[version='<4'] -> funcsigs[version='>=1.0']
# numba -> funcsigs
# pytables -> mock -> funcsigs
#
# Package intervaltree conflicts for:
# anaconda==2020.07 -> intervaltree==3.0.2=py_1
# spyder -> intervaltree[version='>=3.0.2']
# anaconda==2020.07 -> spyder==4.1.4=py37_0 -> intervaltree
#
# Package rope conflicts for:
# anaconda==2020.07 -> rope==0.17.0=py_0
# python-language-server -> rope[version='>=0.10.5']
# spyder -> rope[version='>=0.10.5|>=0.9.4']
# anaconda==2020.07 -> python-language-server==0.34.1=py37_0 -> rope[version='>=0.10.5']
#
# Package r-spatial conflicts for:
# r-essentials -> r-recommended[version='>=3.6.0'] -> r-spatial
# r-recommended -> r-spatial
#
# Package twisted conflicts for:
# notebook -> prometheus_client -> twisted
# prometheus_client -> twisted
#
# Package r-pbdzmq conflicts for:
# r-irkernel -> r-pbdzmq[version='>=0.2_1']
# r-essentials -> r-irkernel[version='>=0.8.12'] -> r-pbdzmq[version='>=0.2_1']
#
# Package pbr conflicts for:
# pytables -> mock -> pbr
# mock -> pbr
#
# Package anyio conflicts for:
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> anyio[version='>=2.0.2']
# jupyterlab_server -> jupyter_server[version='>=1.1.0,<2.0.0'] -> anyio[version='>=2.0.2']
#
# Package r-shiny conflicts for:
# rstudio -> r-miniui[version='>=0.1.1'] -> r-shiny[version='0.12.2|>=0.13.2|>=0.13|>=1.0.1|>=1.1.0|>=1.0.5|>=1.0.3|>=0.14.2']
# rstudio -> r-shiny[version='>=1.0']
# r-essentials -> r-shiny[version='0.12.2|>=0.13.2|>=0.14.2|>=1.0.3|>=1.0.5|>=1.1.0']
#
# Package pycosat conflicts for:
# conda-build -> conda[version='>=4.5'] -> pycosat[version='>=0.6.1|>=0.6.3']
# conda[version='>=4.10.3'] -> pycosat[version='>=0.6.3']
# anaconda==2020.07 -> pycosat==0.6.3[build='py38h1de35cc_1|py36h1de35cc_0|py37h1de35cc_0']
#
# Package r-glmnet conflicts for:
# r-essentials -> r-glmnet[version='2.0_2|>=2.0_10|>=2.0_13|>=2.0_16|>=2.0_5']
# rstudio -> r-essentials[version='>=3.4.3'] -> r-glmnet[version='2.0_2|>=2.0_10|>=2.0_13|>=2.0_16|>=2.0_5']
#
# Package r-quantreg conflicts for:
# r-car -> r-quantreg
# r-caret -> r-car -> r-quantreg
#
# Package r-chron conflicts for:
# r-data.table -> r-chron
# r-essentials -> r-data.table[version='>=1.9.6'] -> r-chron
#
# Package werkzeug conflicts for:
# anaconda==2020.07 -> werkzeug==1.0.1=py_0
# flask -> werkzeug[version='>=0.14|>=0.15|>=0.7,<1.0.0']
# anaconda==2020.07 -> flask==1.1.2=py_0 -> werkzeug[version='>=0.15']
#
# Package r-class conflicts for:
# r-essentials -> r-recommended[version='>=3.6.0'] -> r-class
# r-recommended -> r-class
#
# Package zope.event conflicts for:
# anaconda==2020.07 -> gevent==20.6.2=py37haf1e3a3_0 -> zope.event
# anaconda==2020.07 -> zope.event==4.4[build='py38_0|py36_0|py37_0']
# gevent -> zope.event
#
# Package filelock conflicts for:
# conda-build -> filelock
# anaconda==2020.07 -> filelock==3.0.12=py_0
#
# Package dask conflicts for:
# scikit-image -> dask[version='>=0.5']
# anaconda==2020.07 -> dask==2.20.0=py_0
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c https://conda.anaconda.org/chirayu pycausal
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - pycausal -> python[version='2.7.*|>=3.6,<3.7.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cdt
# Out:
# Collecting cdt
#   Downloading cdt-0.5.23-py3-none-any.whl (921 kB)
#      |████████████████████████████████| 921 kB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: networkx in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (2.5.1)
# Requirement already satisfied: requests in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (2.24.0)
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
# Requirement already satisfied: statsmodels in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (0.11.1)
# Requirement already satisfied: scipy in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (1.5.0)
# Requirement already satisfied: numpy in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (1.20.1)
# Requirement already satisfied: tqdm in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (4.47.0)
# Requirement already satisfied: joblib in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (0.16.0)
# Collecting skrebate
#   Downloading skrebate-0.62.tar.gz (19 kB)
# Requirement already satisfied: pandas in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (1.2.2)
# Requirement already satisfied: scikit-learn in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from cdt) (0.24.2)
# Requirement already satisfied: decorator<5,>=4.3 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from networkx->cdt) (4.4.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from requests->cdt) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from requests->cdt) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from requests->cdt) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from requests->cdt) (2.10)
# Requirement already satisfied: patsy>=0.5 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from statsmodels->cdt) (0.5.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from pandas->cdt) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from pandas->cdt) (2.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->cdt) (2.1.0)
# Requirement already satisfied: six in /Users/tomgvero/opt/anaconda3/lib/python3.8/site-packages (from patsy>=0.5->statsmodels->cdt) (1.15.0)
# Building wheels for collected packages: GPUtil, skrebate
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7411 sha256=17bfb77da10e98fa8973ac63bff38e261b2948496cb237694624767e53cfc9e4
#   Stored in directory: /Users/tomgvero/Library/Caches/pip/wheels/ba/03/bb/7a97840eb54479b328672e15a536e49dc60da200fb21564d53
#   Building wheel for skrebate (setup.py) ... done
#   Created wheel for skrebate: filename=skrebate-0.62-py3-none-any.whl size=29256 sha256=8a565e7db92c7d84635360e4049c2981d00973fdb4246fc31d832137e471279b
#   Stored in directory: /Users/tomgvero/Library/Caches/pip/wheels/1e/93/22/f83048fc1dafedcec44bb4ccf8d08225da96d20115d97a7a77
# Successfully built GPUtil skrebate
# Installing collected packages: GPUtil, skrebate, cdt
# Successfully installed GPUtil-1.4.0 cdt-0.5.23 skrebate-0.62
# Note: you may need to restart the kernel to use updated packages.
